# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/Users/renzocahuana/Documents/Coding_dojo/DATA_SETS/The_World's_Highest_Paid_Athletes.xlsx")
df.head()
# Out:
#    Rank               Name       Sport  Total Earnings  On-the-Field Earnings  \
# 0     1  Cristiano Ronaldo      Soccer       136000000               46000000
# 1     2       Lionel Messi      Soccer       130000000               65000000
# 2     3      Kylian Mbappé      Soccer       120000000              100000000
# 3     4       LeBron James  Basketball       119500000               44500000
# 4     5     Canelo Alvarez      Boxing       110000000              100000000
#
#    Off-the-Field Earnings
# 0                90000000
# 1                65000000
# 2                20000000
# 3                75000000
# 4                10000000

# %%
df[df['Name'] == 'Tiger Woods']
# Out:
#     Rank         Name Sport  Total Earnings  On-the-Field Earnings  \
# 15    16  Tiger Woods  Golf        75100000               15100000
#
#     Off-the-Field Earnings
# 15                60000000

# %%
plt.figure(figsize=(12, 8))  
sns.barplot(data=df, x='Sport', y='Total Earnings', palette='viridis')  
plt.xlabel('Sport', fontsize=14)  
plt.ylabel('Total Earnings', fontsize=14)  
plt.title('Total Earnings by Sport', fontsize=16)  
plt.xticks(rotation=45, fontsize=12)  
plt.yticks(fontsize=12)  
plt.grid(axis='y')  
plt.tight_layout()  
plt.show()
# Out:
# /var/folders/r7/_8hlpyjs1471x6vcvkn2l9bm0000gn/T/ipykernel_1904/481955948.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Sport', y='Total Earnings', palette='viridis')

# %% [markdown]
# Given the perception of the American public about American football as the most popular sport and one of the biggest. We can see that among the most popular sports in the world, American football is the least profitable.

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='Sport', y='Off-the-Field Earnings', palette='viridis')  
plt.xlabel('Sport', fontsize=14)  
plt.ylabel('Off-the-Field Earnings', fontsize=14)
plt.title('Off-the-Field Earnings by Sport', fontsize=16) 
plt.xticks(rotation=45, fontsize=12) 
plt.yticks(fontsize=12) 
plt.grid(axis='y')
plt.tight_layout()  
plt.show()
# Out:
# /var/folders/r7/_8hlpyjs1471x6vcvkn2l9bm0000gn/T/ipykernel_1904/3271949117.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Sport', y='Off-the-Field Earnings', palette='viridis')

# %% [markdown]
# In the case of profitability in athletes outside of sporting activities, we can see that, unlike popular perception, tennis is the one that generates the most money off the courts.
